# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_telco=pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df_telco.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df_telco.shape
# Out:
# (7043, 21)

# %%
df_telco.describe
# Out:
# <bound method NDFrame.describe of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df_telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
customer_5=df_telco.iloc[0:,0:5]
print(customer_5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 0     7590-VHVEG  Female              0     Yes         No
# 1     5575-GNVDE    Male              0      No         No
# 2     3668-QPYBK    Male              0      No         No
# 3     7795-CFOCW    Male              0      No         No
# 4     9237-HQITU  Female              0      No         No
# ...          ...     ...            ...     ...        ...
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No
#
# [7043 rows x 5 columns]

# %%
customer_15=df_telco.iloc[0:,6:21]
print(customer_15)
# Out:
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# 1             Yes                No             DSL            Yes
# 2             Yes                No             DSL            Yes
# 3              No  No phone service             DSL            Yes
# 4             Yes                No     Fiber optic             No
# ...           ...               ...             ...            ...
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 0             Yes               No          No          No              No
# ...

# %%
senior_male_electronic=df_telco[(df_telco['gender']=='Male')& (df_telco['SeniorCitizen']==1)&(df_telco['PaymentMethod']=='Electronic check')]
print(senior_male_electronic)
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV   Male              1      No         No       1
# 55    1658-BYGOY   Male              1      No         No      18
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 78    0191-ZHSKZ   Male              1      No         No      30
# 91    2424-WVHPL   Male              1      No         No       1
# ...          ...    ...            ...     ...        ...     ...
# 6837  6229-LSCKB   Male              1      No         No       6
# 6894  1400-MMYXY   Male              1     Yes         No       3
# 6914  7142-HVGBG   Male              1     Yes         No      43
# 6967  8739-WWKDU   Male              1      No         No      25
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
customer_total_tenure=df_telco[(df_telco['tenure'] > 70) | (df_telco['MonthlyCharges']> 100)]
print(customer_total_tenure)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 8             Yes           Yes     Fiber optic                   No  ...
# ...

# %%
two_mail_yes=df_telco[(df_telco['Contract']=='Two year')&(df_telco['PaymentMethod']=='Mailed check')&(df_telco['Churn']=='Yes')]
print(two_mail_yes)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
streaming=df_telco[(df_telco['StreamingTV']=='Yes')| (df_telco['StreamingMovies']=='Yes')]
print(streaming)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 5             Yes               Yes     Fiber optic             No  ...
# ...

# %%
female_dsl=df_telco[(df_telco['gender']=='Female')& (df_telco['InternetService']=='DSL')]
print(female_dsl)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 7     6713-OKOMC  Female              0      No         No      10
# 18    4190-MFLUW  Female              0     Yes        Yes      10
# 23    3638-WEABW  Female              0     Yes         No      58
# 25    6865-JZNKO  Female              0      No         No      30
# ...          ...     ...            ...     ...        ...     ...
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7029  2235-DWLJU  Female              1      No         No       6
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
number=df_telco.shape
print(type(number))
# Out:
# <class 'tuple'>

# %%
print(f"number of rows= {number[0]} and number of columns={number[1]}")
# Out:
# number of rows= 7043 and number of columns=21

# %%
customer_333=df_telco.sample(n=333)
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5584  6330-JKLPC    Male              0     Yes         No      11
# 4613  6987-XQSJT  Female              1      No         No      54
# 3994  0406-BPDVR  Female              1     Yes         No      54
# 5465  6933-FHBZC  Female              0      No         No      26
# 4207  8706-HRADD    Male              0      No         No      21
# ...          ...     ...            ...     ...        ...     ...
# 1317  9277-JOOMO  Female              0      No         No       3
# 4704  1928-BXYIV    Male              0      No         No       1
# 2295  2672-DZUOY    Male              0      No         No       1
# 5005  2359-QWQUL  Female              0     Yes         No      39
# 5816  0374-IOEGQ  Female              0      No         No       3
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 5584          Yes               Yes     Fiber optic                   No  ...
# ...

# %%
df_telco['Churn'].value_counts()
# Out:
# <bound method IndexOpsMixin.value_counts of 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7043, dtype: object>

# %%
customer_total_tenure.to_csv('customer.csv')

# %% [markdown]
# ## used cars in uk

# %%
df_cars=pd.read_csv('/content/used_cars_UK.csv')

# %%
df_cars.head()
# Out:
#    Unnamed: 0           title  Price  Mileage(miles)  Registration_Year  \
# 0           0     SKODA Fabia   6900           70189               2016
# 1           1  Vauxhall Corsa   1495           88585               2008
# 2           2     Hyundai i30    949          137000               2011
# 3           3      MINI Hatch   2395           96731               2010
# 4           4  Vauxhall Corsa   1000           85000               2013
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              NaN    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              NaN    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   Emission Class Service history
# 0         Euro 6             NaN
# 1         Euro 4            Full
# ...

# %%
df_cars.shape
# Out:
# (3685, 14)

# %%
budget_cars=df_cars[(df_cars['Price']>5000)&(df_cars['Mileage(miles)']>50000)]
budget_cars
# Out:
#       Unnamed: 0                  title  Price  Mileage(miles)  \
# 0              0            SKODA Fabia   6900           70189
# 12            12            SKODA Fabia   6900           70189
# 13            14           BMW 3 Series  19800           69690
# 21            22     Mercedes-Benz A180  14498           53055
# 25            26  Mercedes-Benz A Class  15900           62402
# ...          ...                    ...    ...             ...
# 3596        4628              SEAT Leon   5495          128000
# 3600        4635              SEAT Leon   5495          128000
# 3625        4664     Vauxhall Astra GTC   7495           50312
# 3638        4678         Nissan Qashqai   7995           67000
# 3681        4724                Audi A4   6990          119000
#
#       Registration_Year  Previous Owners              Fuel type  Body type  \
# 0                  2016              3.0                 Diesel  Hatchback
# ...

# %%
diesel_hatchback=df_cars[(df_cars['Body type']=='Hatchback')&(df_cars['Fuel type']=='Diesel')]
diesel_hatchback
# Out:
#       Unnamed: 0           title  Price  Mileage(miles)  Registration_Year  \
# 0              0     SKODA Fabia   6900           70189               2016
# 4              4  Vauxhall Corsa   1000           85000               2013
# 9              9     Peugeot 207   1299           87000               2008
# 10            10     Ford Fiesta   1495          181693               2009
# 12            12     SKODA Fabia   6900           70189               2016
# ...          ...             ...    ...             ...                ...
# 3654        4695  Vauxhall Corsa   1995          126000               2013
# 3656        4697    Toyota Auris   1295          158469               2008
# 3669        4711  Renault Megane   2489          129000               2013
# 3670        4712       Fiat Idea   1295           84000               2007
# 3678        4721      Citroen C3   1795           85962               2009
#
# ...

# %%
cars=df_cars[(df_cars['Body type']=='Hatchback')&(df_cars['Gearbox']=='Manual')|(df_cars['Body type']=='MPV')&(df_cars['Gearbox']=='Automatic')]
cars
# Out:
#       Unnamed: 0           title  Price  Mileage(miles)  Registration_Year  \
# 0              0     SKODA Fabia   6900           70189               2016
# 1              1  Vauxhall Corsa   1495           88585               2008
# 2              2     Hyundai i30    949          137000               2011
# 3              3      MINI Hatch   2395           96731               2010
# 4              4  Vauxhall Corsa   1000           85000               2013
# ...          ...             ...    ...             ...                ...
# 3674        4717  Vauxhall Astra   4999           60139               2015
# 3678        4721      Citroen C3   1795           85962               2009
# 3679        4722  Nissan Qashqai   1695          104000               2009
# 3680        4723  Renault Megane   1395           76202               2006
# 3684        4727  Vauxhall Corsa   2000           82160               2013
#
# ...

# %%
count=(df_cars['Registration_Year']>=2015).value_counts()
count
# Out:
# False    2555
# True     1130
# Name: Registration_Year, dtype: int64
