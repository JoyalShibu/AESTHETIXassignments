# %% [markdown]
# import panda

# %%
import pandas as pd

# %% [markdown]
# read csv file

# %%
df=pd.read_csv("/content/Salaries.csv")

# %% [markdown]
# List first 5 records

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %% [markdown]
# list last 5 records

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %% [markdown]
# check a particular column

# %%
print(df['salary'])
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %% [markdown]
# check a particular column type

# %%
df['salary'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# check types for all columns

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %% [markdown]
# columns

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %% [markdown]
# shape

# %%
df.shape
# Out:
# (78, 6)

# %% [markdown]
# values

# %%
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %% [markdown]
# mean

# %%
print(df.mean())
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64
# <ipython-input-19-f98cceecb4a0>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.mean())

# %% [markdown]
# salary mean

# %%
print(df['salary'].mean())
# Out:
# 108023.78205128205

# %% [markdown]
# # Calculate mean salary for each professor rank

# %%
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %% [markdown]
# mean for sex

# %%
df.groupby('sex')[['salary']].mean()
# Out:
#                salary
# sex
# Female  101002.410256
# Male    115045.153846

# %% [markdown]
# ## Calculate mean salary for each professor rank

# %%
df_sub=df[df['salary']>120000]


print(df_sub)
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %% [markdown]
# # select columns

# %%
df[['rank','salary']]
# Out:
#          rank  salary
# 0        Prof  186960
# 1        Prof   93000
# 2        Prof  110515
# 3        Prof  131205
# 4        Prof  104800
# ..        ...     ...
# 73       Prof  105450
# 74  AssocProf  104542
# 75       Prof  124312
# 76       Prof  109954
# 77       Prof  109646
#
# [78 rows x 2 columns]

# %% [markdown]
# select rows

# %%
df[10:20]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 11      Prof          B   23       23  Male  134778
# 12  AsstProf          B    1        0  Male   88000
# 13      Prof          B   35       33  Male  162200
# 14      Prof          B   25       19  Male  153750
# 15      Prof          B   17        3  Male  150480
# 16  AsstProf          B    8        3  Male   75044
# 17  AsstProf          B    4        0  Male   92000
# 18      Prof          A   19        7  Male  107300
# 19      Prof          A   29       27  Male  150500

# %% [markdown]
# # Select rows by their labels:

# %%
df_sub.loc[10:20,['rank','sex','salary']]
# Out:
#     rank   sex  salary
# 10  Prof  Male  128250
# 11  Prof  Male  134778
# 13  Prof  Male  162200
# 14  Prof  Male  153750
# 15  Prof  Male  150480
# 19  Prof  Male  150500

# %% [markdown]
# #shape of df_sub

# %%
df_sub.shape
# Out:
# (25, 6)

# %% [markdown]
# #Select rows by their labels:

# %%
df_sub.iloc[10:20,[0,3,4,5]]
# Out:
#     rank  service     sex  salary
# 26  Prof       19    Male  148750
# 27  Prof       43    Male  155865
# 29  Prof       20    Male  123683
# 31  Prof       21    Male  155750
# 35  Prof       23    Male  126933
# 36  Prof       45    Male  146856
# 39  Prof       18  Female  129000
# 40  Prof       36  Female  137000
# 44  Prof       19  Female  151768
# 45  Prof       25  Female  140096

# %%
df.iloc[0]# First row of a data frame
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           49
# sex             Male
# salary        186960
# Name: 0, dtype: object

# %%
df.iloc[-1] #last row
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %%
df.iloc[:,0] #first column
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.iloc[0:7]#first 7 rows
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285

# %%
df.iloc[[0,5],[1,3]]#1st and 6th, 3rd and 1
# Out:
#   discipline  service
# 0          B       49
# 5          A       20

# %%
#Create a new data frame from the original sorted by the column SERVICE
df_sorted=df.sort_values(by='service')
df_sorted.head()
df_sorted.tail()
# Out:
#     rank discipline  phd  service     sex  salary
# 40  Prof          A   39       36  Female  137000
# 27  Prof          A   45       43    Male  155865
# 36  Prof          B   45       45    Male  146856
# 0   Prof          B   56       49    Male  186960
# 9   Prof          A   51       51    Male   57800

# %%
#ascending service descending salary
df_sorted=df.sort_values(by=['service','salary'],ascending=[True,False])
df_sorted.head(10)
# Out:
#         rank discipline  phd  service     sex  salary
# 52      Prof          A   12        0  Female  105000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# 55  AsstProf          A    2        0  Female   72500
# 57  AsstProf          A    3        1  Female   72500
# 28  AsstProf          B    7        2    Male   91300
# 42  AsstProf          B    4        2  Female   80225
# 68  AsstProf          A    4        2  Female   77500

# %% [markdown]
# ##HOTEL BOOKINGS

# %%
df_hotels=pd.read_csv("/content/hotel_bookings.csv")

# %%
df_hotels.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df_hotels.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df_hotels.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df_hotels.shape
# Out:
# (119390, 32)

# %%
df_hotels['hotel'].unique
# Out:
# <bound method Series.unique of 0         Resort Hotel
# 1         Resort Hotel
# 2         Resort Hotel
# 3         Resort Hotel
# 4         Resort Hotel
#               ...
# 119385      City Hotel
# 119386      City Hotel
# 119387      City Hotel
# 119388      City Hotel
# 119389      City Hotel
# Name: hotel, Length: 119390, dtype: object>

# %% [markdown]
# ## check a particular column

# %%
print(df_hotels['is_canceled'])
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 119385    0
# 119386    0
# 119387    0
# 119388    0
# 119389    0
# Name: is_canceled, Length: 119390, dtype: int64

# %% [markdown]
# ## check a particular column

# %%
df_hotels['is_canceled'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## columns

# %%
df_hotels.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ## values

# %%
df_hotels.values
# Out:
# array([['Resort Hotel', 0, 342, ..., 0, 'Check-Out', '2015-07-01'],
#        ['Resort Hotel', 0, 737, ..., 0, 'Check-Out', '2015-07-01'],
#        ['Resort Hotel', 0, 7, ..., 0, 'Check-Out', '2015-07-02'],
#        ...,
#        ['City Hotel', 0, 34, ..., 4, 'Check-Out', '2017-09-07'],
#        ['City Hotel', 0, 109, ..., 0, 'Check-Out', '2017-09-07'],
#        ['City Hotel', 0, 205, ..., 2, 'Check-Out', '2017-09-07']],
#       dtype=object)

# %% [markdown]
# ## mean

# %%
print(df_hotels.mean())
# Out:
# is_canceled                          0.370416
# lead_time                          104.011416
# arrival_date_year                 2016.156554
# arrival_date_week_number            27.165173
# arrival_date_day_of_month           15.798241
# stays_in_weekend_nights              0.927599
# stays_in_week_nights                 2.500302
# adults                               1.856403
# children                             0.103890
# babies                               0.007949
# is_repeated_guest                    0.031912
# previous_cancellations               0.087118
# previous_bookings_not_canceled       0.137097
# booking_changes                      0.221124
# agent                               86.693382
# company                            189.266735
# days_in_waiting_list                 2.321149
# adr                                101.831122
# required_car_parking_spaces          0.062518
# total_of_special_requests            0.571363
# dtype: float64
# ...

# %% [markdown]
# ## arrival date year

# %%
print(df_hotels['company'].mean())
# Out:
# 189.26673532440782

# %% [markdown]
# ## calculate arrivals for each hotel

# %%
df_hotels.groupby('hotel')[['company']].mean()
# Out:
#                  company
# hotel
# City Hotel    145.271618
# Resort Hotel  241.486165

# %% [markdown]
# ##select columns

# %%
df_hotels[['hotel','arrival_date_year']]
# Out:
#                hotel  arrival_date_year
# 0       Resort Hotel               2015
# 1       Resort Hotel               2015
# 2       Resort Hotel               2015
# 3       Resort Hotel               2015
# 4       Resort Hotel               2015
# ...              ...                ...
# 119385    City Hotel               2017
# 119386    City Hotel               2017
# 119387    City Hotel               2017
# 119388    City Hotel               2017
# 119389    City Hotel               2017
#
# [119390 rows x 2 columns]

# %% [markdown]
# ## selects rows

# %%
df_hotels[10:20]
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# 15  Resort Hotel            0         68               2015
# 16  Resort Hotel            0         37               2015
# 17  Resort Hotel            0         12               2015
# 18  Resort Hotel            0          0               2015
# 19  Resort Hotel            0          7               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 10               July                        27                          1
# 11               July                        27                          1
# 12               July                        27                          1
# ...

# %% [markdown]
# ## select rows by their labels

# %%
df_hotels.loc[10:20,['hotel','company','arrival_date_year']]
# Out:
#            hotel  company  arrival_date_year
# 10  Resort Hotel      NaN               2015
# 11  Resort Hotel      NaN               2015
# 12  Resort Hotel      NaN               2015
# 13  Resort Hotel      NaN               2015
# 14  Resort Hotel      NaN               2015
# 15  Resort Hotel      NaN               2015
# 16  Resort Hotel      NaN               2015
# 17  Resort Hotel      NaN               2015
# 18  Resort Hotel    110.0               2015
# 19  Resort Hotel      NaN               2015
# 20  Resort Hotel      NaN               2015

# %% [markdown]
# ## select rows by their rows

# %%
df_hotels.iloc[10:20,[0,3,5,7,12]]
# Out:
#            hotel  arrival_date_year  arrival_date_week_number  \
# 10  Resort Hotel               2015                        27
# 11  Resort Hotel               2015                        27
# 12  Resort Hotel               2015                        27
# 13  Resort Hotel               2015                        27
# 14  Resort Hotel               2015                        27
# 15  Resort Hotel               2015                        27
# 16  Resort Hotel               2015                        27
# 17  Resort Hotel               2015                        27
# 18  Resort Hotel               2015                        27
# 19  Resort Hotel               2015                        27
#
#     stays_in_weekend_nights meal
# 10                        0   BB
# 11                        0   HB
# 12                        0   BB
# 13                        0   HB
# 14                        0   BB
# 15                        0   BB
# 16                        0   BB
# ...

# %% [markdown]
# # first row of a data frame

# %%
df_hotels.iloc[0]
# Out:
# hotel                             Resort Hotel
# is_canceled                                  0
# lead_time                                  342
# arrival_date_year                         2015
# arrival_date_month                        July
# arrival_date_week_number                    27
# arrival_date_day_of_month                    1
# stays_in_weekend_nights                      0
# stays_in_week_nights                         0
# adults                                       2
# children                                   0.0
# babies                                       0
# meal                                        BB
# country                                    PRT
# market_segment                          Direct
# distribution_channel                    Direct
# is_repeated_guest                            0
# previous_cancellations                       0
# previous_bookings_not_canceled               0
# reserved_room_type                           C
# ...

# %% [markdown]
# #last row

# %%
df_hotels.iloc[-1]
# Out:
# hotel                             City Hotel
# is_canceled                                0
# lead_time                                205
# arrival_date_year                       2017
# arrival_date_month                    August
# arrival_date_week_number                  35
# arrival_date_day_of_month                 29
# stays_in_weekend_nights                    2
# stays_in_week_nights                       7
# adults                                     2
# children                                 0.0
# babies                                     0
# meal                                      HB
# country                                  DEU
# market_segment                     Online TA
# distribution_channel                   TA/TO
# is_repeated_guest                          0
# previous_cancellations                     0
# previous_bookings_not_canceled             0
# reserved_room_type                         A
# assigned_room_type                         A
# ...

# %% [markdown]
# # first column

# %%
df_hotels.iloc[:,0]
# Out:
# 0         Resort Hotel
# 1         Resort Hotel
# 2         Resort Hotel
# 3         Resort Hotel
# 4         Resort Hotel
#               ...
# 119385      City Hotel
# 119386      City Hotel
# 119387      City Hotel
# 119388      City Hotel
# 119389      City Hotel
# Name: hotel, Length: 119390, dtype: object

# %% [markdown]
# ## first 7 rows

# %%
df_hotels.iloc[0:7]
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
# ...

# %%
df_hotels.iloc[[0,5],[12,24]]
# Out:
#   meal  company
# 0   BB      NaN
# 5   BB      NaN

# %% [markdown]
# ## create a new data frame from the original sorted by the column COMPANY

# %%
df_hotels_sorted=df_hotels.sort_values(by='adr')
df_hotels_sorted.head()
df_hotels_sorted.tail()
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 13142   Resort Hotel            1        378               2017
# 103912    City Hotel            0         81               2016
# 15083   Resort Hotel            0          1               2015
# 111403    City Hotel            0          0               2017
# 48515     City Hotel            1         35               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 13142              August                        31
# 103912           December                        53
# 15083                July                        29
# 111403                May                        19
# 48515               March                        13
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 13142                           1                        4
# 103912                         31                        1
# 15083                          15                        0
# ...

# %% [markdown]
# ##ascending adr descending agents

# %%
df_hotels_sorted=df_hotels.sort_values(by=['adr','agent'],ascending=[True,False])
df_hotels_sorted.head(10)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 14969   Resort Hotel            0        195               2017
# 33468   Resort Hotel            0          1               2017
# 35550   Resort Hotel            0        109               2017
# 39126   Resort Hotel            0        235               2017
# 30500   Resort Hotel            0         34               2016
# 30936   Resort Hotel            0         48               2016
# 111709    City Hotel            0         31               2017
# 38866   Resort Hotel            0         45               2017
# 38878   Resort Hotel            0         25               2017
# 40016   Resort Hotel            0         87               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 14969               March                        10
# 33468              August                        35
# 35550               April                        17
# ...
