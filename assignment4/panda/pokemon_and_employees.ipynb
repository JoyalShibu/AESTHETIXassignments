# %%
import pandas as pd

# %%
df_pokemon=pd.read_csv("/content/Pokemon.csv")

# %%
df_pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
print(df_pokemon['Type 1'])
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df_pokemon.describe
# Out:
# <bound method NDFrame.describe of        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df_pokemon.iloc[10:20,[0,1,2,12]]
# Out:
#      #                     Name Type 1  Legendary
# 10   8                Wartortle  Water      False
# 11   9                Blastoise  Water      False
# 12   9  BlastoiseMega Blastoise  Water      False
# 13  10                 Caterpie    Bug      False
# 14  11                  Metapod    Bug      False
# 15  12               Butterfree    Bug      False
# 16  13                   Weedle    Bug      False
# 17  14                   Kakuna    Bug      False
# 18  15                 Beedrill    Bug      False
# 19  15    BeedrillMega Beedrill    Bug      False

# %%
df_fire=df_pokemon[df_pokemon['Type 1']=='Fire']

# %%
df_fire
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
df_fire_sorted=df_fire.sort_values(by = 'Speed', ascending=False)
df_fire_sorted.head()
# Out:
#        #        Name Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 731  663  Talonflame   Fire    Flying    499  78      81       71       74
# 437  392   Infernape   Fire  Fighting    534  76     104       71      104
# 736  668      Pyroar   Fire    Normal    507  86      68       72      109
# 84    78    Rapidash   Fire       NaN    500  65     100       70       80
# 723  655     Delphox   Fire   Psychic    534  75      69       72      114
#
#      Sp. Def  Speed  Generation  Legendary
# 731       69    126           6      False
# 437       71    108           4      False
# 736       66    106           6      False
# 84        80    105           1      False
# 723      100    104           6      False

# %%
df_pokemon['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df_pokemon['Type 2'].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
df_pokemon.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df_c=df_pokemon.fillna(df_pokemon.mode().iloc[3])
df_c.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
import matplotlib.pyplot as plt

# %%
df_pokemon.plot(kind = 'scatter', x='Attack', y = 'Defense')
plt.show()

# %%
counts=df_pokemon['Legendary'].value_counts()
counts.plot(kind='bar')
plt.xlabel('Legendary')
plt.ylabel('Legendary')
plt.show()

# %%
counts=df_pokemon['Type 1'].value_counts()
counts.plot(kind='bar')
plt.xlabel('Type 1')
plt.ylabel('Type 1')
plt.show()

# %% [markdown]
# ##Employee

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df_employee=pd.read_csv("/content/Employee.csv")

# %%
df_employee.head(25)
# Out:
#     Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0   Bachelors         2017  Bangalore            3   34    Male          No
# 1   Bachelors         2013       Pune            1   28  Female          No
# 2   Bachelors         2014  New Delhi            3   38  Female          No
# 3     Masters         2016  Bangalore            3   27    Male          No
# 4     Masters         2017       Pune            3   24    Male         Yes
# 5   Bachelors         2016  Bangalore            3   22    Male          No
# 6   Bachelors         2015  New Delhi            3   38    Male          No
# 7   Bachelors         2016  Bangalore            3   34  Female          No
# 8   Bachelors         2016       Pune            3   23    Male          No
# 9     Masters         2017  New Delhi            2   37    Male          No
# 10    Masters         2012  Bangalore            3   27    Male          No
# ...

# %%
df_gender=df_employee[df_employee['Gender']=='Male']
df_gender.head(10)
# Out:
#     Education  JoiningYear       City  PaymentTier  Age Gender EverBenched  \
# 0   Bachelors         2017  Bangalore            3   34   Male          No
# 3     Masters         2016  Bangalore            3   27   Male          No
# 4     Masters         2017       Pune            3   24   Male         Yes
# 5   Bachelors         2016  Bangalore            3   22   Male          No
# 6   Bachelors         2015  New Delhi            3   38   Male          No
# 8   Bachelors         2016       Pune            3   23   Male          No
# 9     Masters         2017  New Delhi            2   37   Male          No
# 10    Masters         2012  Bangalore            3   27   Male          No
# 11  Bachelors         2016       Pune            3   34   Male          No
# 12  Bachelors         2018       Pune            3   32   Male         Yes
#
#     ExperienceInCurrentDomain  LeaveOrNot
# 0                           0           0
# 3                           5           1
# ...

# %%
df_employee.iloc[10:20,[0,3,4,5]]
# Out:
#     Education  PaymentTier  Age  Gender
# 10    Masters            3   27    Male
# 11  Bachelors            3   34    Male
# 12  Bachelors            3   32    Male
# 13  Bachelors            3   39    Male
# 14  Bachelors            3   37    Male
# 15  Bachelors            1   29    Male
# 16  Bachelors            3   34  Female
# 17  Bachelors            3   34    Male
# 18  Bachelors            2   30  Female
# 19  Bachelors            2   22  Female

# %%
df_employee.plot(kind = 'scatter', x='Age', y = 'ExperienceInCurrentDomain')
plt.show()

# %%
counts=df_employee['Education'].value_counts()
counts.plot(kind='bar')
plt.xlabel('Education')
plt.ylabel('Education')
plt.show()
